# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import textract

# %%
english_stopwords = set(STOPWORDS)
with open('stop_words.txt') as file:
    portuguese_stopwords = {line.strip() for line in file}
stopwords = english_stopwords.union(portuguese_stopwords)

# %%
planogoverno_txt = textract.process("pdfs/plano_governo_AlvaroDias.pdf").decode('utf-8')
with open('txt/plano_governo_AlvaroDias.txt', 'w') as file:
    file.write(planogoverno_txt)

# %%
wordcloud = WordCloud(min_font_size = 20, 
                      max_font_size = 300,
                      width = 2000,
                      height = 1000,
                      mode = "RGB",
                      normalize_plurals = True,
                      stopwords = stopwords).generate(planogoverno_txt)
plt.figure(figsize = (16,9))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
plt.savefig('pics/wordcloud_AlvaroDias.png', bbox_inches='tight', transparent = True, pad_inches = 0)
plt.show()
